# %% [markdown]
# B) Estructura final recomendada (15 min)
#
# Introducción y contexto – Qué problema atacamos
#
# Planteamiento del problema – ¿Tiene sentido usar ML aquí?
#
# Datos – Origen, estructura y preparación
#
# EDA y visualización – Qué aprendemos antes de modelar
#
# Modelos probados – Qué modelos y por qué
#
# Overfitting y decisiones técnicas – Qué problema real aparece
#
# Resultados – Métricas + lectura correcta
#
# Impacto y decisiones – Qué permitiría hacer esto
#
# Limitaciones y próximos pasos
#
# Demo Streamlit + cierre
#
# C) Versión final slide-by-slide (copy-ready)
# Slide 1 — Introducción
#
# Título
# 📊 Predicción de movimientos diarios en criptomonedas con ML y Streamlit
#
# Bullets
#
# Proyecto de Machine Learning aplicado a series temporales financieras
#
# Clasificación binaria: ¿el retorno diario será positivo o negativo?
#
# Visualización, modelado y análisis en una app interactiva con Streamlit
#
# Nota del presentador (40–50s)
#
# Este proyecto surge como trabajo de ML para clase. Además de entrenar modelos, decidí presentar el resultado como una app en Streamlit porque me permite unir análisis, visualización y modelos en un flujo claro y profesional.
#
# Slide 2 — Problema a resolver
#
# Título
# ❓ ¿Qué problema intentamos resolver?
#
# Bullets
#
# Los mercados cripto son volátiles y difíciles de interpretar día a día
#
# Queremos anticipar la dirección del retorno diario
#
# El objetivo no es predecir precios exactos, sino tendencia
#
# Nota (40s)
#
# No buscamos hacer trading automático ni predecir precios exactos. El problema se formula como clasificación binaria: subir o bajar. Esto simplifica el problema y lo hace más realista para ML.
#
# Slide 3 — ¿Tiene sentido usar ML?
#
# Título
# 🤔 ¿Podemos solucionarlo con Machine Learning?
#
# Bullets
#
# Datos históricos abundantes
#
# Relaciones no lineales entre variables
#
# Enfoque supervisado con target definido
#
# Riesgo claro: overfitting en series temporales
#
# Nota (45s)
#
# Aquí es importante ser críticos: ML puede ayudar, pero también es fácil sobreajustar. Por eso el foco del proyecto no es solo “tener buen score”, sino entender qué está pasando.
#
# Slide 4 — Datos
#
# Título
# 📂 Datos utilizados
#
# Bullets
#
# Dataset de Kaggle con históricos diarios de criptomonedas
#
# Variables: retornos, volatilidad, métricas temporales
#
# Target: retorno diario > 0 (1) / ≤ 0 (0)
#
# Split temporal (sin shuffle)
#
# Nota (40s)
#
# Al ser series temporales, respetamos el orden temporal. No mezclamos pasado y futuro, algo clave para evitar data leakage.
#
# Slide 5 — Limpieza y preparación
#
# Título
# 🧼 Limpieza y feature engineering
#
# Bullets
#
# Eliminación de columnas no informativas
#
# Tratamiento de nulos
#
# Conversión de fechas e indexado temporal
#
# Construcción explícita del target
#
# Nota (40s)
#
# Esta parte es clave. Mucho del rendimiento del modelo depende más de aquí que del modelo en sí.
#
# Slide 6 — Análisis exploratorio (EDA)
#
# Título
# 📈 Qué nos dicen los datos
#
# Bullets
#
# Correlaciones entre variables numéricas
#
# Relación volatilidad–retorno
#
# Distribución del target
#
# Evolución temporal suavizada
#
# Nota (50s)
#
# Antes de entrenar nada, exploramos patrones. Por ejemplo, la volatilidad aparece como una variable relevante, lo cual luego se refleja en los modelos.
#
# Slide 7 — Modelos probados
#
# Título
# 🤖 Modelos de ML utilizados
#
# Bullets
#
# Regresión Logística (baseline)
#
# Random Forest
#
# XGBoost
#
# Métrica principal: ROC AUC
#
# Nota (40s)
#
# Empiezo con un modelo simple y luego paso a modelos más complejos. Esto me permite comparar y detectar problemas como el overfitting.
#
# Slide 8 — Problema detectado: overfitting
#
# Título
# ⚠️ Overfitting en modelos complejos
#
# Bullets
#
# RF y XGB aprenden demasiado bien el training
#
# Caída de generalización en test
#
# Riesgo real en datos financieros
#
# Decisión consciente: limitar complejidad
#
# Nota (50s)
#
# Aquí aparece el principal problema del proyecto. En vez de ocultarlo, lo uso como aprendizaje y justifico decisiones técnicas.
#
# Slide 9 — Resultados
#
# Título
# 📊 Resultados obtenidos
#
# Bullets
#
# Regresión logística: baseline estable
#
# RF y XGB: mayor capacidad, más riesgo
#
# Métricas interpretadas con cautela
#
# No se persigue “el mejor score”
#
# Nota (45s)
#
# Lo importante no es decir “mi modelo acierta X%”, sino entender cuándo y por qué falla.
#
# Slide 10 — Impacto y decisiones
#
# Título
# 💡 ¿Qué decisiones permitiría este modelo?
#
# Bullets
#
# Señales de tendencia diaria
#
# Apoyo a análisis exploratorio
#
# Filtro previo a decisiones humanas
#
# Base para sistemas más complejos
#
# Nota (40s)
#
# Esto no sustituye a nadie, pero puede ayudar a priorizar decisiones o análisis.
#
# Slide 11 — Streamlit como solución
#
# Título
# 🖥️ ¿Por qué Streamlit?
#
# Bullets
#
# Integra datos, modelos y visualizaciones
#
# Flujo claro para usuario técnico
#
# Reproducible y sin dependencias externas
#
# Ideal para demos y proyectos académicos
#
# Nota (40s)
#
# Streamlit no es solo “para enseñar”, también obliga a ordenar el proyecto.
#
# Slide 12 — Limitaciones y próximos pasos
#
# Título
# 🚧 Limitaciones y futuro
#
# Bullets
#
# Overfitting en modelos complejos
#
# No se usan datos en tiempo real
#
# Falta validación rolling
#
# Posible regularización y tuning futuro
#
# Nota (45s)
#
# Reconocer limitaciones suma puntos. Aquí dejo claro que sé qué mejoraría el proyecto.
#
# Slide 13 — Cierre
#
# Título
# ✅ Conclusión
#
# Bullets
#
# Problema realista y bien planteado
#
# ML usado con criterio
#
# Streamlit como valor añadido
#
# Proyecto sólido y extensible
#
# Nota (30s)
#
# Cierro reforzando que no es solo código, sino razonamiento.
